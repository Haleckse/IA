# %%
import pandas as pd
import numpy as np
import matplotlib . pyplot as plt
import seaborn as sns
from scipy import stats

fromages = pd.read_csv("fromage.csv")

print(fromages.describe()) 

fromages.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# z:\IA\TP5\tp5.ipynb Cell 1 line 7
#       <a href='vscode-notebook-cell:/z%3A/IA/TP5/tp5.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/z%3A/IA/TP5/tp5.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> from scipy import stats
# ----> <a href='vscode-notebook-cell:/z%3A/IA/TP5/tp5.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> fromages = pd.read_csv("fromage.csv")
#       <a href='vscode-notebook-cell:/z%3A/IA/TP5/tp5.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> print(fromages.describe())
#      <a href='vscode-notebook-cell:/z%3A/IA/TP5/tp5.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> fromages.head()
#
# ...

# %%
sns.pairplot(fromages)

# %% [markdown]
# Variables corrélées :
# calories, magnesium
# calories, lipides
# calories, cholesterol
# calories, proteines
#
# calcium, magnesium
# calcium, proteines
#
#
# lipides, proteines
# lipides, cholesterol
# lipides, magnesium
#
# proteines, cholesterol

# %%
fromages_sans_nom = fromages.drop(columns='name ')


fromages_sans_nom.head()
print(fromages.columns)

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram , linkage
from pylab import rcParams
rcParams ['figure.figsize'] = 8,10
# generate the linkage matrix Ward method
Z = linkage (fromages_sans_nom, method = 'centroid' , metric = 'manhattan')
# plotting the dendrogram
plt.title ("CAH")
dendrogram (Z , labels=fromages['name '].values , orientation = 'left' , color_threshold =0)
plt.show ()
# Out:
# Index(['name ', ' calories ', ' sodium ', ' calcium ', ' lipides ',
#        ' retinol ', ' folates ', ' proteines ', ' cholesterol ', ' magnesium'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# z:\IA\TP5\tp5.ipynb Cell 4 line 1
#      <a href='vscode-notebook-cell:/z%3A/IA/TP5/tp5.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> rcParams ['figure.figsize'] = 8,10
#      <a href='vscode-notebook-cell:/z%3A/IA/TP5/tp5.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> # generate the linkage matrix Ward method
# ---> <a href='vscode-notebook-cell:/z%3A/IA/TP5/tp5.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> Z = linkage (fromages_sans_nom, method = 'centroid' , metric = 'Manhattan')
#      <a href='vscode-notebook-cell:/z%3A/IA/TP5/tp5.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> # plotting the dendrogram
# ...

# %%
import matplotlib
mpl_toolkits.mplot3d
